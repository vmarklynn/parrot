# %%
import os
import whisper
import torch
from pyannote.audio import Pipeline
from pyannote.core import Segment, Annotation, Timeline
import datetime
from transformers import BartTokenizer, BartModel, pipeline

# %%
def remove_suffix(filename):
    return filename.replace(".wav", "")

# %%
# Taken from https://github.com/yinruiqing/pyannote-whisper
class PyanWhisper:
    PUNC_SENT_END = ['.', '?', '!']
        
    def diarize_text(transcribe_res, diarization_result):
        timestamp_texts = PyanWhisper.get_text_with_timestamp(transcribe_res)
        spk_text = PyanWhisper.add_speaker_info_to_text(timestamp_texts, diarization_result)
        res_processed = PyanWhisper.merge_sentence(spk_text)
        return res_processed

    def get_text_with_timestamp(transcribe_res):
        timestamp_texts = []
        for item in transcribe_res['segments']:
            start = item['start']
            end = item['end']
            text = item['text']
            timestamp_texts.append((Segment(start, end), text))
        return timestamp_texts
    
    def add_speaker_info_to_text(timestamp_texts, ann):
        spk_text = []
        for seg, text in timestamp_texts:
            spk = ann.crop(seg).argmax()
            spk_text.append((seg, spk, text))
        return spk_text
    
    def merge_cache(text_cache):
        sentence = ''.join([item[-1] for item in text_cache])
        spk = text_cache[0][1]
        start = text_cache[0][0].start
        end = text_cache[-1][0].end
        return Segment(start, end), spk, sentence
    
    def merge_sentence(spk_text):
        merged_spk_text = []
        pre_spk = None
        text_cache = []
        for seg, spk, text in spk_text:
            if spk != pre_spk and pre_spk is not None and len(text_cache) > 0:
                merged_spk_text.append(PyanWhisper.merge_cache(text_cache))
                text_cache = [(seg, spk, text)]
                pre_spk = spk
            elif text[-1] in PyanWhisper.PUNC_SENT_END:
                text_cache.append((seg, spk, text))
                merged_spk_text.append(PyanWhisper.merge_cache(text_cache))
                text_cache = []
                pre_spk = spk
            else:
                text_cache.append((seg, spk, text))
                pre_spk = spk
        if len(text_cache) > 0:
            merged_spk_text.append(PyanWhisper.merge_cache(text_cache))
        return merged_spk_text

    def write_to_txt(spk_sent, file):
        with open(file, 'w') as fp:
            for seg, spk, sentence in spk_sent:
                line = f'{seg.start:.2f} {seg.end:.2f} {spk} {sentence}\n'
                fp.write(line)

# %%
model = whisper.load_model("base", device="cuda")
# pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization@2.1",
#                                     use_auth_token="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")

# %%
input_directory = "../../../Pipeline/sample_input2/"
output_directory = "../../../Pipeline/output_pure_whisper/"

# %%
for filename in os.listdir(input_directory):
    audio = os.path.join(input_directory, filename)
    text = os.path.join(output_directory, remove_suffix(filename))
    print("Input:" + audio)
    print("Output:" + text)
    result = model.transcribe(audio)
    #diarization = pipeline(audio)
    #final_result = PyanWhisper.diarize_text(result, diarization)
    print(result["text"])

#     with open(text + '.txt', 'w+') as f:
#         for seg, spk, sent in final_result:
#             start = str(datetime.timedelta(seconds=int(seg.start)))
#             line = start + f'\t{spk}\n{sent}\n\n'
#             f.write(line)
# Out:
# Input:../../../Pipeline/sample_input2/Bed015.interaction.wav
# Output:../../../Pipeline/output_pure_whisper/Bed015.interaction
#  what things to talk about. Really? Oh, it was horrible. It was incentive. You recorded it? Hello? Hello? Yeah. Which one? All right, good. OK. OK. Did you do something? OK. And I guess I'm doing something. So basically, the result of much thinking since the last time we met, but not as much writing, is a sheet that I have a lot of thoughts and justification to comment on. But I'll just pass out as is right now. So here's what's around. And there's two things. So one on one side is a revised, updated semantics specification. The other side is revised. This is just one sheet, right? No, just one sheet. OK. So this thing also. And it's very similar to the reverse. If you change it, it's always more. But before I don't think everyone here is seen all of this. So sure, here, begin. As usual, the disclaimers are there. All these things are, it's only slightly worse people than it was before. And after a little bit more discussion, especially that people that I have formerly missed at all in the next release, probably changing that so far. Maybe I will, let's start with number two, actually, on the notation. Because that's thinking possible, and there are more familiar to people. OK. So the top block is just sort of a abstract technique, sort of like those things are the kinds of things that we can have. And certain things that have changed, to have changed back to this, that there's been a little bit of going back and forth. But basically, obviously, all the constructions have some kind of name. I forgot to include that you could have a type included in this line, so it's like, well, there's an example. The text for example, the end, it has a causal construction. So just to show it doesn't have to be a beautiful way to get people to be able to send text as well. These three have various ways of doing certain things. I'll just try to go through them. So they could all have a type at the beginning. And then they say the keyword construction. Oh, I see. So the current syntax is, if there's a type, it's before construct. OK, that's fine. OK. And then it has a block that is constituents. And as usual, I guess all the constructions here, all the examples here have only one type of constituent that is a constructional constituent. I think that's actually going to turn out to be certainly the most common kind. But in general, instead of the word construct, there are clear who might have meaning or form as well. So there's some element that isn't yet constructional, and this is the maps one and meaning. OK. The main change with the constructs, which each of which has a keyword construct, and then some name, and then some type of classification, is that it's often, sometimes the case in the first case here that you know what kind of construction is. So for example, whatever I have here, it's going to be a form of the word throw, or it's going to be a word, you know, happy, or something like that. Some people may be a specific word, or maybe you'll have the type, you'll say, I need a spatial relation for easier. I need a directional decimal right here. You could have an actual type here. Or you could just say, in the same case, that you only know the meaning of type. So a very common example is this one that, you know, in directed motion, the first person to do some nature of being agent of some kind, often a human, right? So if I run down the street, then I, I run as a chief, it's type, I mean, the category is what's there. But the new kind is this one is sort of a pair. And sort of skipping the moths and whatever. The idea is that sometimes there are general constructors that you know that you're going to be equivalent of a noun phrase, or a noun phrase, or something like that. And usually it has a whole consideration that I don't want with it. And then you might know something much more specific, depending on what construction you're going to go about, what meaning, what specific you want. So the example, again, at the bottom of a directed ...
